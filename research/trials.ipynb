# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1-ocwrtBy9B8fZOQnCPIN50M7Oh3Rmr_v/view?usp=sharing"
type(url)
file_id = url.split('/')[-2]
file_id
# Out:
# '1-ocwrtBy9B8fZOQnCPIN50M7Oh3Rmr_v'

# %%
prefix = 'https://drive.google.com/uc?export=download&id='
gdown.download(prefix + file_id, 'MRI_dataset.zip')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1-ocwrtBy9B8fZOQnCPIN50M7Oh3Rmr_v
# From (redirected): https://drive.google.com/uc?export=download&id=1-ocwrtBy9B8fZOQnCPIN50M7Oh3Rmr_v&confirm=t&uuid=b5bbb0c6-4498-4db2-a1b3-f506cdb0fd55
# To: f:\UOM\FYP\MLFlow_project\research\MRI_dataset.zip
# 100%|██████████| 156M/156M [03:06<00:00, 837kB/s]
# 'MRI_dataset.zip'
